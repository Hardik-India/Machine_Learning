# %% [markdown]
# <a href="https://colab.research.google.com/github/Hardik-India/Machine_Learning/blob/main/BGD_in__nD_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score

# %%
x,y = load_diabetes(return_X_y=True)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
print("Betas value : ",reg.coef_)
print("Intercept value : ",reg.intercept_)
# Out:
# Betas value :  [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# Intercept value :  151.88331005254167

# %%
class GDRegressor:

  def __init__(self,learning_rate,epochs):
    self.coef_ = None
    self.intercept_ = None
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,x_train,y_train):
    # initialize the coef with all ones and the intercept with 0
    self.intercept_ = 0
    self.coef_ = np.ones(x_train.shape[1])

    for i in range(self.epochs):
      # update all the coefs and intercept

      y_hat = np.dot(x_train,self.coef_) + self.intercept_

      # calculating the intercept values
      intercept_der = -2 * np.mean(y_train - y_hat)
      self.intercept_ = self.intercept_ - (self.lr * intercept_der)

      # calculating the coefficient values
      coef_der = -2 * np.dot((y_train - y_hat),x_train)/x_train.shape[0]
      self.coef_ = self.coef_ - (self.lr * coef_der)

  def predict(self,x_test):
    return np.dot(x_test,self.coef_) + self.intercept_

# %%
gd = GDRegressor(epochs=200000,learning_rate=0.98)

# %%
gd.fit(x_train,y_train)

# %%
gd.coef_
# Out:
# array([  -9.15799349, -205.45168231,  516.70021522,  340.61871243,
#        -895.23222132,  560.96683821,  153.75081702,  126.69076423,
#         861.0074275 ,   52.42172341])

# %%
gd.intercept_
# Out:
# np.float64(151.88331362114695)

# %%
y_pred = gd.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399363159463684

# %%
print("Betas value : ",reg.coef_)
print("Intercept value : ",reg.intercept_)
# Out:
# Betas value :  [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# Intercept value :  151.88331005254167
